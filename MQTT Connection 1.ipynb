# %% [markdown]
# Checking the connection possibility

# %%
# Import SDK packages
from AWSIoTPythonSDK.MQTTLib import AWSIoTMQTTShadowClient
import pandas as pd
import time
import json
import numpy as np
from json import dumps
from datetime import datetime

# %%
# For certificate based connection
myShadowClient = AWSIoTMQTTShadowClient("A0206753E_01")

# Configurations
# For TLS mutual authentication
myShadowClient.configureEndpoint("a18rvi21phvz6r-ats.iot.ap-southeast-1.amazonaws.com", 8883)

myShadowClient.configureCredentials('Amazon_Root_CA_1.pem.crt.txt', '8e4331113d-private.pem.key', '8e4331113d-certificate.pem.crt')

myShadowClient.configureConnectDisconnectTimeout(10)  # 10 sec
myShadowClient.configureMQTTOperationTimeout(5)  # 5 sec
myShadowClient.connect()
## Create a device shadow instance using persistent subscription
myDeviceShadow = myShadowClient.createShadowHandlerWithName("A0206753E_01", True)

# %%
def myShadowUpdateCallback(payload, responseStatus, token):
  print()
  print('UPDATE: $aws/things/' + 'A0206753E_01' +
    '/shadow/update/#')

# %%
Ed = pd.read_csv('train_FD001.csv',header=None)
Col1 = Ed[0][:]
y = np.asarray(list(map(str,Col1)))
x = np.full(len(Ed),"FD001_")
A = np.char.add(x,y)
B = np.full(len(Ed),"A0206753E")
Ed.loc[:,[0]] = A
C = np.asarray(Ed)
data = np.insert(C,1,B, axis=1)

# %%
def json_serial(obj):
    if isinstance(obj,datetime):
        return obj.isoformat() 

for i in range(20):
    t = datetime.utcnow()
#word = {"state": {"reported": {"timestamp":t, "id": "FD001_XX", "message": "We are with ISRO"}}}
    word = {"id": data[i][0],"timestamp":t, "Matric ID": data[i][1], "cycle" :data[i][2], "OS1" :data[i][3], "OS2" :data[i][4], "OS3" :data[i][5],
           "S1" :data[i][6],"S2":data[i][7],"S3":data[i][8],"S4":data[i][9],"S5":data[i][10],"S6":data[i][11],"S7":data[i][12],
           "S8":data[i][13],"S9":data[i][14],"S10":data[i][15],"S11":data[i][16],"S12":data[i][17],"S13":data[i][18],"S14":data[i][19],
           "S15":data[i][20],"S16":data[i][21],"S17":data[i][22],"S18":data[i][23],"S19":data[i][24],"S20":data[i][25],"S21":data[i][26]}
    Imp =json.dumps(word, default=json_serial)
    print(Imp)
     
    ## Shadow operations
    myDeviceShadow.shadowGet(myShadowUpdateCallback, 5)
    myDeviceShadow.shadowUpdate(Imp, myShadowUpdateCallback, 5)
    time.sleep(10)
# Out:
# {"id": "FD001_1", "timestamp": "2019-09-20T13:30:43.108946", "Matric ID": "A0206753E", "cycle": 1, "OS1": -0.0007, "OS2": -0.0004, "OS3": 100, "S1": 518.67, "S2": 641.82, "S3": 1589.7, "S4": 1400.6, "S5": 14.62, "S6": 21.61, "S7": 554.36, "S8": 2388.06, "S9": 9046.19, "S10": 1.3, "S11": 47.47, "S12": 521.66, "S13": 2388.02, "S14": 8138.62, "S15": 8.4195, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 39.06, "S21": 23.419}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13

#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:32:07.271713", "Matric ID": "A0206753E", "cycle": 9, "OS1": 0.0008, "OS2": 0.0001, "OS3": 100, "S1": 518.67, "S2": 642.12, "S3": 1590.98, "S4": 1394.8, "S5": 14.62, "S6": 21.61, "S7": 553.69, "S8": 2388.05, "S9": 9046.46, "S10": 1.3, "S11": 47.29, "S12": 521.79, "S13": 2388.05, "S14": 8125.69, "S15": 8.3728, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 39.05, "S21": 23.4066}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:32:17.276795", "Matric ID": "A0206753E", "cycle": 10, "OS1": -0.0033, "OS2": 0.0001, "OS3": 100, "S1": 518.67, "S2": 641.71, "S3": 1591.24, "S4": 1400.46, "S5": 14.62, "S6": 21.61, "S7": 553.59, "S8": 2388.05, "S9": 9051.7, "S10": 1.3, "S11": 47.03, "S12": 521.79, "S13": 2388.06, "S14": 8129.38, "S15": 8.4286, "S16": 0.03, "S17": 393.0, "S18": 2388.0, "S19": 100.0, "S20": 38.95, "S21": 23.4694}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:32:27.282748", "Matric ID": "A0206753E", "cycle": 11, "OS1": 0.0018, "OS2": -0.0003, "OS3": 100, "S1": 518.67, "S2": 642.28, "S3": 1581.75, "S4": 1400.64, "S5": 14.62, "S6": 21.61, "S7": 554.54, "S8": 2388.05, "S9": 9049.61, "S10": 1.3, "S11": 47.15, "S12": 521.4, "S13": 2388.01, "S14": 8140.58, "S15": 8.434, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 38.94, "S21": 23.4787}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:32:37.288384", "Matric ID": "A0206753E", "cycle": 12, "OS1": 0.0016, "OS2": 0.0002, "OS3": 100, "S1": 518.67, "S2": 642.06, "S3": 1583.41, "S4": 1400.15, "S5": 14.62, "S6": 21.61, "S7": 554.52, "S8": 2388.09, "S9": 9049.37, "S10": 1.3, "S11": 47.18, "S12": 521.8, "S13": 2388.02, "S14": 8134.25, "S15": 8.3938, "S16": 0.03, "S17": 391.0, "S18": 2388.0, "S19": 100.0, "S20": 39.06, "S21": 23.366}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:32:47.293424", "Matric ID": "A0206753E", "cycle": 13, "OS1": -0.0019, "OS2": 0.0004, "OS3": 100, "S1": 518.67, "S2": 643.07, "S3": 1582.19, "S4": 1400.83, "S5": 14.62, "S6": 21.61, "S7": 553.44, "S8": 2388.12, "S9": 9046.82, "S10": 1.3, "S11": 47.38, "S12": 521.85, "S13": 2388.08, "S14": 8128.1, "S15": 8.4152, "S16": 0.03, "S17": 393.0, "S18": 2388.0, "S19": 100.0, "S20": 38.93, "S21": 23.2757}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:32:57.299025", "Matric ID": "A0206753E", "cycle": 14, "OS1": 0.0009, "OS2": 0.0, "OS3": 100, "S1": 518.67, "S2": 642.35, "S3": 1592.95, "S4": 1399.16, "S5": 14.62, "S6": 21.61, "S7": 554.48, "S8": 2388.09, "S9": 9047.37, "S10": 1.3, "S11": 47.44, "S12": 521.67, "S13": 2388.0, "S14": 8134.43, "S15": 8.3964, "S16": 0.03, "S17": 393.0, "S18": 2388.0, "S19": 100.0, "S20": 39.18, "S21": 23.3826}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:33:07.305055", "Matric ID": "A0206753E", "cycle": 15, "OS1": -0.0018, "OS2": -0.0003, "OS3": 100, "S1": 518.67, "S2": 642.43, "S3": 1583.82, "S4": 1402.13, "S5": 14.62, "S6": 21.61, "S7": 553.64, "S8": 2388.11, "S9": 9052.22, "S10": 1.3, "S11": 47.3, "S12": 522.5, "S13": 2388.08, "S14": 8127.56, "S15": 8.4199, "S16": 0.03, "S17": 391.0, "S18": 2388.0, "S19": 100.0, "S20": 38.99, "S21": 23.35}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:33:17.310100", "Matric ID": "A0206753E", "cycle": 16, "OS1": 0.0006, "OS2": 0.0005, "OS3": 100, "S1": 518.67, "S2": 642.13, "S3": 1587.98, "S4": 1404.5, "S5": 14.62, "S6": 21.61, "S7": 553.94, "S8": 2388.05, "S9": 9049.34, "S10": 1.3, "S11": 47.24, "S12": 521.49, "S13": 2388.07, "S14": 8136.11, "S15": 8.3936, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 38.97, "S21": 23.455}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:33:27.315053", "Matric ID": "A0206753E", "cycle": 17, "OS1": 0.0002, "OS2": 0.0002, "OS3": 100, "S1": 518.67, "S2": 642.58, "S3": 1584.96, "S4": 1399.95, "S5": 14.62, "S6": 21.61, "S7": 553.8, "S8": 2388.06, "S9": 9054.92, "S10": 1.3, "S11": 47.12, "S12": 521.89, "S13": 2388.04, "S14": 8137.27, "S15": 8.4542, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 38.81, "S21": 23.3319}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:33:37.320082", "Matric ID": "A0206753E", "cycle": 18, "OS1": -0.0031, "OS2": -0.0001, "OS3": 100, "S1": 518.67, "S2": 642.62, "S3": 1591.04, "S4": 1396.12, "S5": 14.62, "S6": 21.61, "S7": 554.2, "S8": 2388.05, "S9": 9049.55, "S10": 1.3, "S11": 47.21, "S12": 521.76, "S13": 2388.07, "S14": 8132.73, "S15": 8.4028, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 38.89, "S21": 23.3987}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:33:47.326078", "Matric ID": "A0206753E", "cycle": 19, "OS1": 0.0032, "OS2": -0.0003, "OS3": 100, "S1": 518.67, "S2": 641.79, "S3": 1587.56, "S4": 1400.35, "S5": 14.62, "S6": 21.61, "S7": 554.18, "S8": 2388.04, "S9": 9053.99, "S10": 1.3, "S11": 47.4, "S12": 521.89, "S13": 2388.03, "S14": 8129.13, "S15": 8.4321, "S16": 0.03, "S17": 391.0, "S18": 2388.0, "S19": 100.0, "S20": 38.8, "S21": 23.3464}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
# {"id": "FD001_1", "timestamp": "2019-09-20T13:33:57.333980", "Matric ID": "A0206753E", "cycle": 20, "OS1": -0.0037, "OS2": 0.0001, "OS3": 100, "S1": 518.67, "S2": 643.04, "S3": 1581.11, "S4": 1405.23, "S5": 14.62, "S6": 21.61, "S7": 554.81, "S8": 2388.05, "S9": 9045.9, "S10": 1.3, "S11": 47.22, "S12": 522.07, "S13": 2388.02, "S14": 8129.71, "S15": 8.421, "S16": 0.03, "S17": 392.0, "S18": 2388.0, "S19": 100.0, "S20": 39.03, "S21": 23.421999999999997}
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
#
# UPDATE: $aws/things/A0206753E_01/shadow/update/#
